# %%
import requests

# %%
url = 'https://kumparan.com/@kumparannews/erick-thohir-najwa-dan-wishnutama-tidak-masuk-tim-sukses-1536400040559240664'
page = requests.get(url)

from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html data-react-checksum="1923722788" data-reactid="1" data-reactroot="" lang="id-ID">
#  <head data-reactid="2">
#   <title data-react-helmet="true" data-reactid="3">
#    Erick Thohir: Najwa dan Wishnutama Tidak Masuk Tim Sukses - kumparan
#   </title>
#   <meta charset="utf-8" data-react-helmet="true" data-reactid="4"/>
#   <meta content="index, follow" data-react-helmet="true" data-reactid="5" name="robots"/>
#   <meta content="Erick mengatakan, image Najwa dan Wishnutama lebih cenderung di posisi independen." data-react-helmet="true" data-reactid="6" name="description"/>
#   <meta data-react-helmet="true" data-reactid="7" name="keywords"/>
#   <meta content="News,Politik,Najwa Shihab,Erick Thohir,Pilpres 2019" data-react-helmet="true" data-reactid="8" name="news_keywords"/>
#   <meta content="summary_large_image" data-react-helmet="true" data-reactid="9" name="twitter:card"/>
# ...

# %%
soup.find('h1').get_text()
# Out:
# 'Erick Thohir: Najwa dan Wishnutama Tidak Masuk Tim Sukses'

# %%
soup.find_all(class_='article-text')[0].get_text()
# Out:
# 'Erik Thohir di ruang tunggu Rumah Cemara, Jakarta, Jumat (07/09/2018). (Foto: Fanny Kusumawardhani/kumparan)Najwa Shihab dan Wishnutama termasuk dua tokoh muda yang selalu disebut-sebut masuk Tim Kampanye Nasional (TKN) atau Tim Sukses Jokowi-Ma’ruf Amin. Namun, dipastikan keduanya tidak masuk list.Kepastian tidak ada nama Najwa dan Wishnutama masuk list ini disampaikan langsung Ketua TKN Jokowi-Ma’ruf Amin, Erick Thohir. “Baik Najwa maupun Wishnutama tidak ada di dalam list yang akan kami resmikan,” kata Erick kepada kumparan, Sabtu (8/9). Sebagaimana Erick, baik Najwa maupun Wishnutama, merupakan dua tokoh muda yang kini digandrungi kaum milenial. Najwa, presenter ternama yang juga owner NarasiTV. Sedangkan Wishnutama merupakan dirut Net.TV yang juga komisaris kumparan, yang sedang naik daun karena sukses memesona masyarakat Indonesia terkait pembukaan dan penutupan Asian Games 2018 beberapa waktu lalu. Najwa Shihab. (Foto: Nugroho Sejati/kumparan)Erick mengatakan, image Najwa dan
# ...

# %%
url = 'https://kumparan.com/'

# %%
page = requests.get(url)

from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# soup.find_all('h4')

# %%
for title in soup.find_all('h4'):
    print(title.parent()[0].get_text())
# Out:
# Korban Tewas Kecelakaan Bus di Cikidang Sukabumi Jadi 23 Orang
# Prabowo Hadiahkan Keris Emas ke Djoko Santoso
# Polling: Jokowi-Ma'ruf Amin vs Prabowo-Sandi
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# UMK Bogor Naik Terus, Produsen Jaket Merek Hugo Boss Pilih Pakai Mesin
# 5 Fakta Menarik Perhelatan Asian Games 2018
# Kata Gerindra Soal #2019GantiPresiden ke #2019PrabowoPresiden
# Khofifah - Emil Adakan Syukuran Bersama Relawan dan Atlet Asian Games
# Toyota Buka Suara Soal Sienta Terbaru
# Pertama Dalam 3 Tahun, Pria Korsel Terdiagnosis Terjangkit MERS
# Hotman Sindir SBY soal Polemik Roy Suryo Sambil Ketuk Mangkuk
# AHY Bergabung di Tim Sukses Prabowo - Sandi
# Lipstik yang Ludes Terjual Karena Drama Korea

# %%
for link in soup.find_all(class_='btn-block'):
    link['href']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-86e14ab602b9> in <module>()
#       1 for link in soup.find_all(class_='btn-block'):
# ----> 2     link['href']
#
# /anaconda3/lib/python3.6/site-packages/bs4/element.py in __getitem__(self, key)
#    1009         """tag[key] returns the value of the 'key' attribute for the tag,
#    1010         and throws an exception if it's not there."""
# -> 1011         return self.attrs[key]
#    1012
#    1013     def __iter__(self):
#
# KeyError: 'href'

# %%
soup.find_all(class_='btn-block')
# Out:
# [<a class="btn-block" data-reactid="180" href="/sukabumi-update/korban-tewas-kecelakaan-bus-di-cikidang-sukabumi-bertambah-jadi-23-orang-1536405568488176568"><div class="progressive replace" data-reactid="181" id="img-korban-tewas-kecelakaan-bus-di-cikidang-sukabumi-bertambah-jadi-23-orang-1536405568488176568"><img alt="Korban Tewas Kecelakaan Bus di Cikidang Sukabumi Jadi 23 Orang" class="preview" data-reactid="182" src="https://alibaba.kumpar.com/kumpar/image/upload/q_auto:low,f_jpg,fl_lossy,c_fill,g_face,w_640,ar_16:9/56_cjbihc.jpg" style="width:100%;"/></div></a>,
#  <a class="btn-block" data-reactid="183" href="/sukabumi-update/korban-tewas-kecelakaan-bus-di-cikidang-sukabumi-bertambah-jadi-23-orang-1536405568488176568"><h4 data-reactid="184">Korban Tewas Kecelakaan Bus di Cikidang Sukabumi Jadi 23 Orang</h4></a>,
# ...
